# %%
#Sum of numbers using *args.

def sum_numbers(*args):
    return sum(args)
print(sum_numbers(1,2,3,4))
# Out:
# 10

# %%
#Count number of arguments.

def count_args(*args):
    return len(args)
print(count_args(1,2,3,4,5))
# Out:
# 5

# %%
#Find maximum value.

def find_max(*args):
    return max(args)
print(find_max(10,20,5,40))
# Out:
# 40

# %%
#Print each argument.

def print_items(*args):
    for item in args:
        print(item)
print_items("Apple","Banana","Mango")
# Out:
# Apple
# Banana
# Mango

# %%
#Multiply numbers.

def multiply_numbers(*args):
    result=1
    for num in args:
        result*=num
    return result
print(multiply_numbers(2,3,4))
# Out:
# 24

# %%
#Greet user using **Kwargs.

def greet_user(**Kwargs):
    if "name" in kwargs:
        print("Hello",kwargs["name"])
    else:
        print("Hello Guest")
    greet_user(name="Shubham")

# %%
#Print key values pair.

def print_details(**Kwargs):
    for key,value in Kwargs.items():
        print(key,":",value)
print_details(name="Debu",city="Dewas",age=20)
# Out:
# name : Debu
# city : Dewas
# age : 20

# %%
#Student profile.

def student_profile(**Kwargs):
    if "name" in Kwargs:
        print("Name:",Kwargs["name"])
    if "course" in Kwargs:
        print("Course:",Kwargs["course"])
    if "city" in Kwargs:
        print("City:",Kwargs["city"])
student_profile(name="Aditi",course="Datascience",city="Dewas")
# Out:
# Name: Aditi
# Course: Datascience
# City: Dewas

# %%
#Average of numbers.

def average_marks(*args):
    return sum(args)/len(args)
print(average_marks(80,90,70))
# Out:
# 80.0

# %%
#Get even numbers.

def get_even_numbers(*args):
    even=[]
    for num in args:
        even.append(num)
    return even
print(get_even_numbers(1,2,4,5,7,9,0,8))
# Out:
# [1, 2, 4, 5, 7, 9, 0, 8]

# %%
#Student name and marks.

def student_info(name,*marks):
    print("Student:",name)
    print("Marks:",marks)
student_info("Riya",80,90,75)
# Out:
# Student: Riya
# Marks: (80, 90, 75)

# %%
#Student info with details.

def student_info(name,*marks,**details):
    print("Name:",name)
    print("Marks:",marks)

    for key,value in details.items():
        print(key,":",value)
student_info("Aditi",80,90,95,course="Datascience",city="Dewas")
# Out:
# Name: Aditi
# Marks: (80, 90, 95)
# course : Datascience
# city : Dewas

# %%
#Nested function square.

def calculate_square(n):
    def square():
        return n*n
    return square()
print(calculate_square(5))
# Out:
# 25

# %%
#create message.

def create_message(name):
    def format_message():
        return "Hello " + name + ", Welcome!"
    return format_message()

print(create_message("Aditi"))
# Out:
# Hello Aditi, Welcome!

# %%
#Clculator with nested functions.

def calculator(a,b,op):

    def add():
        return a+b
    def subtract():
        return a-b
    def multiply():
        return a*b
    if op=="add":
        return add()
    elif op=="subtract":
        return subtract()
    elif op=="multiply":
        return multiply()
print(calculator(10,5,"add"))
# Out:
# 15

# %%
#Login Validation.

def login(username,password):
    def validate():
        if username=="admin" and password=="1234":
            return "Login Successful"
        else:
            return "Invalid Credentials"
    return validate()
print(login("admin","1234"))
# Out:
# Login Successful

# %%
#Outer and inner function.

def outer_function(x):
    def inner_function(y):
        return x+y
    return inner_function
result=outer_function(10)
print(result(5))
# Out:
# 15

# %%
#Calculate rectangle area.

def calculate_area(length,width):
    def area():
        return length*width
    return area()
print(calculate_area(5,4))
# Out:
# 20

# %%
#Longest substring without repeating integers.

s=input("Enter a string:")
max_len=0

for i in range(len(s)):
    temp=""
    for j in range(i,len(s)):
        if s[j] not in temp:
            temp+=s[j]
            if len(temp)>max_len:
                max_len=len(temp)
            else:
                break
print("Longest length:",max_len)
# Out:
# Longest length: 6

# %%
#Group a list of words in anagrams.

words=["eat","tea","tan","ate","nat","bat"]
result={}

for word in words:
    key="".join(sorted(word))

    if key not in result:
        result[key]=[]
    result[key].append(word)
print(list(result.values()))
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %%
#Run length encoding.

def run_length_encode(s):
    result=" "
    count=1
    for i in range(1,len(s)):
        if s[i]==s[i-1]:
            count +=1
        else:
            result +=s[i-1]+ str(count)
            count=1
    result+=s[-1]+str(count)
    return result
print(run_length_encode("aaabbcddd"))
# Out:
#  a3b2c1d3

# %%
#First non-repeating character.

def first_non_repeating(s):
    freq={}

    for char in s:
        freq[char]=freq.get(char,0)+1
    for char in s:
        if freq[char]==1:
            return char
    return None
print(first_non_repeating("aabbcdde"))
# Out:
# c

# %%
#Flatten nested list

def flatten(lst):
    result=[]
    for i in lst:
        if type(i)==list:
            result+=flatten(i)
        else:
            result.append(i)
    return result
print(flatten([1,[2,[3,4],5],[6]]))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#Rotate list righr by K.

lst=[1,2,3,4,5]
k=2
k=k % len(lst)
result=lst[-k:] + lst[:-k]
print(result)
# Out:
# [4, 5, 1, 2, 3]

# %%
#Find duplicate elements.

lst=[1,2,3,2,4,1,5]
dup=[]

for i in lst:
    if lst.count(i)> 1:
        dup.append(i)
print("Duplicates",dup)
# Out:
# Duplicates [1, 2, 2, 1]

# %%
#Merge overlapping intervals.

intervals=[[1,3],[2,6],[8,10],[9,12]]
intervals.sort()
merged=[intervals[0]]

for i in intervals[1:]:
    last=merged[-1]
    if i[0]<=last[1]:
        last[1]=max(last[1],i[1])
    else:
        merged.append(i)
    print(merged)
# Out:
# [[1, 6]]
# [[1, 6], [8, 10]]
# [[1, 6], [8, 12]]

# %%
#Second largest element

lst=[10,20,4,45,99]
largest=second=-999999
for i in lst:
    if i>largest:
        second=largest
        largest=i
    elif i>second and i !=largest:
        second=i
print("Second largest:",second)
# Out:
# Second largest: 45

# %%
#Frequency of tuple elements.

t=(1,2,2,3,1,4)
freq={}
for i in t:
    if i in freq:
        freq[i]+=1
    else:
        freq[i]=1
print(freq)
# Out:
# {1: 2, 2: 2, 3: 1, 4: 1}

# %%
#Swap first and last elements of tuple.

t=(1,2,3,4)
lst=list(t)
lst[0],lst[-1],lst[0]
t2=tuple(lst)
print(t2)
# Out:
# (1, 2, 3, 4)

# %%
#Symmetric difference of 2 sets.

a={1,2,3}
b={3,4,5}

result=set()

for i in a:
    if i not in b:
        result.add(i)
    for i in b:
        if i not in a:
            result.add(i)
print(result)
# Out:
# {1, 2, 4, 5}

# %%
#Check subset.

a={1,2}
b={1,2,3,4}

flag=True
for i in a:
    if i not in b:
        flag=false
print(flag)
# Out:
# True

# %%
#Remove duplicates but keep order.

lst=[1,2,2,2,1,4]
result=[]
for i in lst:
    if i not in result:
        result.append(i)
print(result)
# Out:
# [1, 2, 4]

# %%
#Invert Dictionary

d={'a':1,'b':2,'c':1}
result={}
for k,v in d.items():
    if v not in result:
        result[v]=[]
    result[v].append(k)
print(result)
# Out:
# {1: ['a', 'c'], 2: ['b']}

# %%
#Students with highest total marks.

students = {
"Aditi":{"math":90,"eng":85,"sci":88},
"Shubham":{"math":92,"eng":80,"sci":91},
"Neha":{"math":85,"eng":95,"sci":89}
}

topper = ""
max_total = 0

for student in students:
    
    total = 0
    
    for subject in students[student]:
        total += students[student][subject]
    
    if total > max_total:
        max_total = total
        topper = student

print("Topper:", topper)
print("Total Marks:", max_total)
# Out:
# Topper: Neha
# Total Marks: 269
